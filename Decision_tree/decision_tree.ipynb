# %%
from sklearn import datasets

dataset = datasets.load_iris()
X = dataset.data
Y = dataset.target
print('Feature names:', dataset.feature_names, 'Size:', dataset.data.shape)
print('Target names:', dataset.target_names, 'Size:', dataset.target.shape)
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'] Size: (150, 4)
# Target names: ['setosa' 'versicolor' 'virginica'] Size: (150,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.6, test_size=0.4, stratify=Y, random_state=0)
print('Train/Test Sizes:', X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# Train/Test Sizes: (120, 4) (30, 4) (120,) (30,)

# %%
from sklearn.tree import DecisionTreeClassifier

tree_classifier = DecisionTreeClassifier(criterion='gini', random_state=0)
tree_classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, classification_report

Y_preds = tree_classifier.predict(X_test)

print('Actual values:', Y_test)
print('Predicted values:', Y_preds)
print('Test Dataset Accuracy: %.4f' % tree_classifier.score(X_test, Y_test))
print('Training Dataset Accuracy: %.4f' % tree_classifier.score(X_train, Y_train))
print('Confusion Matrix:', confusion_matrix(Y_test, Y_preds), sep='\n')
print('Report:', classification_report(Y_test, Y_preds), sep='\n')
# Out:
# Actual values: [0 1 0 2 0 1 2 0 0 1 2 1 1 2 1 2 2 1 1 0 0 2 2 2 0 1 1 2 0 0]
# Predicted values: [0 1 0 2 0 1 2 0 0 1 2 1 1 2 1 2 2 1 1 0 0 2 2 1 0 1 1 2 0 0]
# Test Dataset Accuracy: 0.9667
# Training Dataset Accuracy: 1.0000
# Confusion Matrix:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  1  9]]
# Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.91      1.00      0.95        10
#            2       1.00      0.90      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
